# %%
from scipy import stats
import numpy as np
import pandas as pd
import os
import csv
from pprint import pprint

# %%
file_path = os.path.join("Resources", "Drug_Overdose.csv")
metadata = pd.read_csv(file_path)
print(f"Data Shape: {metadata.shape}")
metadata.head()
# Out:
# Data Shape: (34944, 12)
#   State  Year  Month           Period  \
# 0    AK  2015  April  12 month-ending
# 1    AK  2015  April  12 month-ending
# 2    AK  2015  April  12 month-ending
# 3    AK  2015  April  12 month-ending
# 4    AK  2015  April  12 month-ending
#
#                                            Indicator  Data Value  \
# 0  Natural & semi-synthetic opioids, incl. methad...         NaN
# 1                                    Cocaine (T40.5)         NaN
# 2      Psychostimulants with abuse potential (T43.6)         NaN
# 3                        Opioids (T40.0-T40.4,T40.6)         NaN
# 4                                   Number of Deaths      4133.0
#
#   Percent Complete  Percent Pending Investigation State Name  \
# 0              100                            0.0     Alaska
# 1              100                            0.0     Alaska
# 2              100                            0.0     Alaska
# 3              100                            0.0     Alaska
# ...

# %%
value_df = metadata[metadata['Year'] >= 2016]

# %%
grouped_multiple = value_df.groupby(['State', 'Indicator'])

# %%
# retrieve the required fields
value_df= pd.DataFrame(value_df[['State', 'Year', 'Month', 'Period','Indicator','Data Value',
                   'Percent Complete','Percent Pending Investigation','Predicted Value']])

value_df.head()
# Out:
#     State  Year  Month           Period  \
# 144    AK  2016  April  12 month-ending
# 145    AK  2016  April  12 month-ending
# 146    AK  2016  April  12 month-ending
# 147    AK  2016  April  12 month-ending
# 148    AK  2016  April  12 month-ending
#
#                                              Indicator  Data Value  \
# 144  Natural & semi-synthetic opioids, incl. methad...        68.0
# 145                                    Cocaine (T40.5)        11.0
# 146                     Number of Drug Overdose Deaths       132.0
# 147      Psychostimulants with abuse potential (T43.6)        35.0
# 148                                   Number of Deaths      4262.0
#
#     Percent Complete  Percent Pending Investigation  Predicted Value
# 144              100                            0.0             68.0
# 145              100                            0.0             11.0
# 146              100                            0.0            132.0
# ...

# %%
drug_table = os.path.join("Resources", "drug_final1.csv")
file_path = pd.read_csv(drug_table)
file_path = file_path
file_path = file_path.rename(columns = {"Data Value": "Death Count"})
file_path = file_path.rename(columns = {"Indicator": "Drug Name"})
file_path.head()
# Out:
#    Unnamed: 0 State  Year  Month           Period  \
# 0           0    AK  2016  April  12 month-ending
# 1           1    AK  2016  April  12 month-ending
# 2           2    AK  2016  April  12 month-ending
# 3           3    AK  2016  April  12 month-ending
# 4           4    AK  2016  April  12 month-ending
#
#                                            Drug Name  Death Count  \
# 0  Natural & semi-synthetic opioids, incl. methad...         68.0
# 1                                    Cocaine (T40.5)         11.0
# 2                     Number of Drug Overdose Deaths        132.0
# 3      Psychostimulants with abuse potential (T43.6)         35.0
# 4                                   Number of Deaths       4262.0
#
#   Percent Complete  Percent Pending Investigation  Predicted Value
# 0              100                            0.0             68.0
# 1              100                            0.0             11.0
# ...

# %%
# retrieve the required fields
file_path= pd.DataFrame(file_path[['State','Year', 'Month', 'Drug Name','Death Count']])

file_path.head()
# Out:
#   State  Year  Month                                          Drug Name  \
# 0    AK  2016  April  Natural & semi-synthetic opioids, incl. methad...
# 1    AK  2016  April                                    Cocaine (T40.5)
# 2    AK  2016  April                     Number of Drug Overdose Deaths
# 3    AK  2016  April      Psychostimulants with abuse potential (T43.6)
# 4    AK  2016  April                                   Number of Deaths
#
#    Death Count
# 0         68.0
# 1         11.0
# 2        132.0
# 3         35.0
# 4       4262.0

# %%
# Specify the file to write to
output_path = os.path.join("Output", "drug_final2.csv")

#save the file
file_path.to_csv(output_path,  index=False)
